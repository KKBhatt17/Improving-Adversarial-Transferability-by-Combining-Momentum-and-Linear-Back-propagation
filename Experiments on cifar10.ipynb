# %%
! git clone https://github.com/qizhangli/linbp-attack.git
# Out:
# Cloning into 'linbp-attack'...
# remote: Enumerating objects: 95, done.
# remote: Counting objects: 100% (95/95), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 95 (delta 19), reused 85 (delta 16), pack-reused 0
# Unpacking objects: 100% (95/95), done.

# %%
! cp -r /content/drive/MyDrive/linbp/cifar-10-batches-py/* /content/linbp-attack/data/cifar10/cifar-10-batches-py

# %%
# ! wget https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# Out:
# --2022-04-06 14:41:27--  https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 170498071 (163M) [application/x-gzip]
# Saving to: ‘cifar-10-python.tar.gz’
#
# cifar-10-python.tar 100%[===================>] 162.60M  73.2MB/s    in 2.2s
#
# 2022-04-06 14:41:30 (73.2 MB/s) - ‘cifar-10-python.tar.gz’ saved [170498071/170498071]

# %%
# ! mv /content/cifar-10-batches-py/* /content/linbp-attack/data/cifar-10-batches-py

# %%
! cp -r /content/linbp-attack/data/cifar-10-batches-py/* /content/drive/MyDrive/linbp/cifar-10-batches-py

# %%
! cp /content/drive/MyDrive/linbp/cifar10_ckpt.tar /content/linbp-attack/attack/cifar10/models

# %%
! cp /content/drive/MyDrive/linbp/selected_cifar10.csv /content/linbp-attack/data/cifar10

# %%
! mv /content/linbp-attack/data/cifar-10-batches-py/* /content/linbp-attack/data/cifar10/cifar-10-batches-py

# %%
# %cd /content/linbp-attack/attack/cifar10/models
# Out:
# /content/linbp-attack/attack/cifar10/models

# %%
! tar -xvf cifar10_ckpt.tar
# Out:
# ckpt/
# ckpt/gdas-cifar10-best.pth
# ckpt/resnext-8x64d/
# ckpt/resnext-8x64d/checkpoint.pth.tar
# ckpt/resnext-8x64d/model_best.pth.tar
# ckpt/resnext-8x64d/log.eps
# ckpt/resnext-8x64d/log.txt
# ckpt/pyramidnet272-checkpoint.pth
# ckpt/vgg19_bn/
# ckpt/vgg19_bn/checkpoint.pth.tar
# ckpt/vgg19_bn/model_best.pth.tar
# ckpt/vgg19_bn/log.eps
# ckpt/vgg19_bn/log.txt
# ckpt/WRN-28-10-drop/
# ckpt/WRN-28-10-drop/checkpoint.pth.tar
# ckpt/WRN-28-10-drop/model_best.pth.tar
# ckpt/WRN-28-10-drop/log.eps
# ckpt/WRN-28-10-drop/log.txt
# ckpt/densenet-bc-L190-k40/
# ckpt/densenet-bc-L190-k40/checkpoint.pth.tar
# ckpt/densenet-bc-L190-k40/model_best.pth.tar
# ckpt/densenet-bc-L190-k40/log.eps
# ckpt/densenet-bc-L190-k40/log.txt

# %%
! mv /content/ckpt/* /content/linbp-attack/attack/cifar10/models/ckpt

# %%
# %cd ../../..
# Out:
# /content/linbp-attack

# %%
! pwd
# Out:
# /content/linbp-attack

# %%
! cp -r /content/drive/MyDrive/linbp/linbp-attack/* /content/linbp-attack

# %%
# %cd /content/linbp-attack
# Out:
# /content/linbp-attack

# %% [markdown]
# ## mifgsm

# %%
! python3 attack/cifar10/attack_vgg19.py --epsilon 0.03 --niters 100 --ila_niters 100 --method mifgsm \
--save_dir data/cifar10/linbp_ila_pgd --batch_size 500

# %%
! python3 attack/cifar10/test.py --dir data/cifar10/linbp_ila_pgd

# %% [markdown]
# ## Linbp+mifgsm

# %%
! python3 attack/cifar10/attack_vgg19.py --epsilon 0.03 --niters 100 --ila_niters 100 --method linbp_mifgsm \
--save_dir data/cifar10/linbp_ila_pgd --batch_size 500
# Out:
# Namespace(batch_size=500, epsilon=0.03, ila_layer=23, ila_niters=100, linbp_layer=23, method='linbp_mifgsm', niters=100, save_dir='data/cifar10/linbp_ila_pgd', target_attack=False)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# batch_0.npy saved
# batch_1.npy saved
# batch_2.npy saved
# batch_3.npy saved
# batch_4.npy saved
# batch_5.npy saved
# batch_6.npy saved
# batch_7.npy saved
# batch_8.npy saved
# batch_9.npy saved
# batch_10.npy saved
# batch_11.npy saved
# batch_12.npy saved
# batch_13.npy saved
# batch_14.npy saved
# batch_15.npy saved
# batch_16.npy saved
# ...

# %%
! python3 attack/cifar10/test.py --dir data/cifar10/linbp_ila_pgd
# Out:
# Namespace(dir='data/cifar10/linbp_ila_pgd')
# /content/linbp-attack/attack/cifar10/models/resnext.py:70: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   init.kaiming_normal(self.classifier.weight)
# /content/linbp-attack/attack/cifar10/models/resnext.py:75: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   init.kaiming_normal(self.state_dict()[key], mode='fan_out')
# vgg19_bn 1.0
# WRN 0.9478
# ResNeXt_29_8_64d 0.9529
# DenseNet_BC_L190_k40 0.9391
# pyramidnet 0.4917
# gdas 0.8303

# %% [markdown]
# ## Linbp only

# %%
! python3 attack/cifar10/attack_vgg19.py --epsilon 0.03 --niters 100 --ila_niters 100 --method linbp_pgd \
--save_dir data/cifar10/linbp_pgd --batch_size 500
# Out:
# Namespace(batch_size=500, epsilon=0.03, ila_layer=23, ila_niters=100, linbp_layer=23, method='linbp_pgd', niters=100, save_dir='data/cifar10/linbp_pgd', target_attack=False)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# batch_0.npy saved
# batch_1.npy saved
# batch_2.npy saved
# batch_3.npy saved
# batch_4.npy saved
# batch_5.npy saved
# batch_6.npy saved
# batch_7.npy saved
# batch_8.npy saved
# batch_9.npy saved
# batch_10.npy saved
# batch_11.npy saved

# %%
! python3 attack/cifar10/test.py --dir data/cifar10/linbp_pgd

# %%
! pwd
# Out:
# /content

# %%
! cp -r /content/linbp-attack/* /content/drive/MyDrive/linbp/linbp-attack

# %%
! cp -r /content/linbp-attack/data/cifar10/linbp_ila_pgd/* /content/drive/MyDrive/linbp/linbp_ila_pgd
